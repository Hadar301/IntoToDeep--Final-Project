# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from enum import Enum
class Pathes(Enum):
  HADAR = 1
  RAN = 2
  ITAMAR = 3

# %% [markdown]
# # Choose User Path

# %%
import sys

##Just choose here the user
path = Pathes.ITAMAR
if(path == Pathes.HADAR):
  PATH='/content/gdrive/My Drive/IntroToDeep/Project/codes/Model_Transformer/Weights.pt'
  sys.path.insert(0,'/content/gdrive/My Drive/IntroToDeep/Project/codes/Model_Transformer')
  train_file = '/content/gdrive/My Drive/IntroToDeep/Project/codes/data/train.txt'
  test_file = '/content/gdrive/My Drive/IntroToDeep/Project/codes/data/test.txt'
  w2v_file = '/content/gdrive/My Drive/IntroToDeep/Project/codes/data/glove.6B.100d.txt'
elif(path == Pathes.RAN):
  PATH='/content/gdrive/My Drive/IntroToDeep/Project/codes/Model_Transformer/Weights.pt'
  sys.path.insert(0,'/content/gdrive/My Drive/IntroToDeep/Project/codes/Model_Transformer')
  train_file = '/content/gdrive/My Drive/IntroToDeep/Project/codes/data/train.txt'
  test_file = '/content/gdrive/My Drive/IntroToDeep/Project/codes/data/test.txt'
  w2v_file = '/content/gdrive/My Drive/IntroToDeep/Project/codes/data/glove.6B.100d.txt'
elif(path == Pathes.ITAMAR):
  PATH='/content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/Weights.pt'
  sys.path.insert(0,'/content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer')
  #train_file = '/content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/data/train.txt'
  train_file = '/content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/data/new_train.txt'
  test_file = '/content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/data/test.txt'
  val_file = '/content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/data/validation.txt'
  w2v_file = '/content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/data/glove.6B.100d.txt'

# %% [markdown]
# # Import code

# %%
from utils import *
from model import *
from config import Config


import torch
import torch.optim as optim
from torch import nn

config = Config()

# %%
config.max_epochs = 10 #Max 35

# %% [markdown]
# # Load Data + Embedding

# %%
##########
#Embedding
##########

dataset = Dataset(config)
dataset.load_data(w2v_file, train_file, test_file, val_file)
# Out:
# 100%|█████████▉| 399999/400000 [00:20<00:00, 19310.03it/s]
# Loaded 128000 training examples
# Loaded 40000 test examples
# Loaded 32000 validation examples

# %% [markdown]
# # Model

# %%
# Create Model with specified optimizer and loss function
##############################################################
model = Transformer(config, len(dataset.vocab))
if torch.cuda.is_available():
    model.cuda()
model.train()
optimizer = optim.Adam(model.parameters(), lr=config.lr)
NLLLoss = nn.NLLLoss()
model.add_optimizer(optimizer)
model.add_loss_op(NLLLoss)
##############################################################

# %% [markdown]
# # Train

# %%
train_losses = []
val_accuracies = []

for i in range(config.max_epochs):
    print ("Epoch: {}".format(i))
  
    train_loss,val_accuracy = model.run_epoch(dataset.train_iterator, dataset.val_iterator, i)
    train_losses.append(train_loss)
    val_accuracies.append(val_accuracy)

train_acc = evaluate_model(model, dataset.train_iterator)
val_acc = evaluate_model(model, dataset.val_iterator)
test_acc = evaluate_model(model, dataset.test_iterator)

print ('Final Training Accuracy: {:.4f}'.format(train_acc))
print ('Final Validation Accuracy: {:.4f}'.format(val_acc))
print ('Final Test Accuracy: {:.4f}'.format(test_acc))

#save weights
print('--------Weights saved------------')
torch.save(model, PATH)
# Out:
# Epoch: 0
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 1
# 	Average training loss: -0.16718
# 	Val Accuracy: 0.0062
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 101
# 	Average training loss: -0.47102
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 201
# 	Average training loss: -0.50464
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 301
# 	Average training loss: -0.49916
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 401
# 	Average training loss: -0.50084
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 501
# 	Average training loss: -0.49740
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 601
# 	Average training loss: -0.49871
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 701
# 	Average training loss: -0.49963
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 801
# 	Average training loss: -0.49731
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 901
# 	Average training loss: -0.50140
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Epoch: 1
# Iter: 1
# 	Average training loss: -0.43889
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 101
# 	Average training loss: -0.50487
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 201
# 	Average training loss: -0.50199
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 301
# 	Average training loss: -0.49829
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 401
# 	Average training loss: -0.49952
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 501
# 	Average training loss: -0.50332
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 601
# 	Average training loss: -0.49890
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 701
# 	Average training loss: -0.49774
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 801
# 	Average training loss: -0.50395
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 901
# 	Average training loss: -0.49610
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Epoch: 2
# Iter: 1
# 	Average training loss: -0.49996
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 101
# 	Average training loss: -0.50300
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 201
# 	Average training loss: -0.49641
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 301
# 	Average training loss: -0.49588
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 401
# 	Average training loss: -0.50596
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 501
# 	Average training loss: -0.50054
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 601
# 	Average training loss: -0.49571
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 701
# 	Average training loss: -0.50224
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 801
# 	Average training loss: -0.49782
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 901
# 	Average training loss: -0.50007
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Epoch: 3
# Reducing LR
# Iter: 1
# 	Average training loss: -0.42208
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 101
# 	Average training loss: -0.49454
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 201
# 	Average training loss: -0.49820
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 301
# 	Average training loss: -0.50210
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 401
# 	Average training loss: -0.50280
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 501
# 	Average training loss: -0.49626
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 601
# 	Average training loss: -0.50615
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 701
# 	Average training loss: -0.49415
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 801
# 	Average training loss: -0.50335
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 901
# 	Average training loss: -0.50031
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Epoch: 4
# Iter: 1
# 	Average training loss: -0.49218
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 101
# 	Average training loss: -0.49088
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 201
# 	Average training loss: -0.50638
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 301
# 	Average training loss: -0.50436
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 401
# 	Average training loss: -0.50249
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 501
# 	Average training loss: -0.49914
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 601
# 	Average training loss: -0.49243
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 701
# 	Average training loss: -0.50008
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 801
# 	Average training loss: -0.49587
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 901
# 	Average training loss: -0.49735
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Epoch: 5
# Iter: 1
# 	Average training loss: -0.50001
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 101
# 	Average training loss: -0.49236
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 201
# 	Average training loss: -0.49821
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 301
# 	Average training loss: -0.49898
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 401
# 	Average training loss: -0.49167
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 501
# 	Average training loss: -0.49955
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 601
# 	Average training loss: -0.50055
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 701
# 	Average training loss: -0.50264
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 801
# 	Average training loss: -0.50264
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 901
# 	Average training loss: -0.50249
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Epoch: 6
# Reducing LR
# Iter: 1
# 	Average training loss: -0.49222
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 101
# 	Average training loss: -0.49883
# 	Val Accuracy: 0.4986
# /content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Transformer/model.py:44: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   return self.softmax(final_out)
# Iter: 201
# 	Average training loss: -0.50219

# %% [markdown]
# #Metrices

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
def evaluate_model_metrices(model, iterator):
    y_all_preds = []
    y_all = []
    for idx,batch in enumerate(iterator):
        if torch.cuda.is_available():
            x = batch.text.cuda()
        else:
            x = batch.text
        #raw value from the model
        y_pred = model(x)
        #Round the raw value to 1 or 2 - cutoff Hyperparameter?
        predicted = torch.max(y_pred.cpu().data, 1)[1] + 1

        #extend all Y_lables, Y_predicted to vectors
        y_all_preds.extend(predicted.numpy())
        y_all.extend(batch.label.numpy())

    accuracy = accuracy_score(y_all, np.array(y_all_preds).flatten())
    #precision, recall, fscore = precision_recall_fscore_support(y_all, y_all_preds, average='binary')
    #returns: score - Accuracy score, 
    #         predicted - Array of predicted raw values (just the last batch)
    #         y_all - all the y labels in a vector
    #         y_all_preds - all the predicted values rounded to 1,2
    #         precision, recall, fscore
    return accuracy, predicted, y_all, y_all_preds, #precision, #recall, fscore

# %% [markdown]
# # New Section

# %%
#get vectors
accuracy, predicted, Y_all, Y_all_Preds = evaluate_model_metrices(model, dataset.test_iterator)

# %%
#Precision/Recall
precision_recall_fscore_support(Y_all, Y_all_Preds, average='binary')

# %%
#Classification Report
print(classification_report(Y_all, Y_all_Preds))

# %%
#Confusion Matrix
cm = confusion_matrix(Y_all, Y_all_Preds, labels=[1,2])
print(cm)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 8))

heatmap = sns.heatmap(cm, annot=True, fmt="d")
heatmap.set_title('confusion matrix TextRNN', fontdict={'fontsize':18}, pad=12);

# %% [markdown]
# # Graphs

# %%
#append to one list
train_loss1 = []
val_accuracies_appended = []

#run until max_epochs 
for i in range(0,config.max_epochs ):
  train_loss1.extend(train_losses[i])
  val_accuracies_appended.extend(val_accuracies[i])

print(train_loss1) 
print(len(train_loss1))
print(val_accuracies_appended) 
print(len(val_accuracies_appended))

# %%
train_loss2 = []
train_loss2 = [x * (-1) for x in train_loss1]

# %%
#print graphs
from matplotlib import pyplot
pyplot.title('Train and Validation Accuracy Trasnformer')
pyplot.plot(train_loss2, label='train')
pyplot.plot(val_accuracies_appended, label='validation')
pyplot.legend()
pyplot.show()

# %% [markdown]
# # Load model to verify

# %%
#load model 
model = torch.load(PATH)
model.eval()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-9-9b5065a04365> in <module>()
#       1 #load model
# ----> 2 model = torch.load(PATH)
#       3 model.eval()
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, **pickle_load_args)
#     605                     opened_file.seek(orig_position)
#     606                     return torch.jit.load(opened_file)
# --> 607                 return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     608         return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#     609
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in _load(zip_file, map_location, pickle_module, pickle_file, **pickle_load_args)
#     880     unpickler = UnpicklerWrapper(data_file, **pickle_load_args)
#     881     unpickler.persistent_load = persistent_load
# --> 882     result = unpickler.load()
#     883
#     884     torch._utils._validate_loaded_sparse_tensors()
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in persistent_load(saved_id)
#     855         data_type, key, location, size = data
#     856         if key not in loaded_storages:
# --> 857             load_tensor(data_type, size, key, _maybe_decode_ascii(location))
#     858         storage = loaded_storages[key]
#     859         return storage
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in load_tensor(data_type, size, key, location)
#     844
#     845         storage = zip_file.get_storage_from_record(name, size, dtype).storage()
# --> 846         loaded_storages[key] = restore_location(storage, location)
#     847
#     848     def persistent_load(saved_id):
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in default_restore_location(storage, location)
#     173 def default_restore_location(storage, location):
#     174     for _, _, fn in _package_registry:
# --> 175         result = fn(storage, location)
#     176         if result is not None:
#     177             return result
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in _cuda_deserialize(obj, location)
#     149 def _cuda_deserialize(obj, location):
#     150     if location.startswith('cuda'):
# --> 151         device = validate_cuda_device(location)
#     152         if getattr(obj, "_torch_load_uninitialized", False):
#     153             storage_type = getattr(torch.cuda, type(obj).__name__)
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in validate_cuda_device(location)
#     133
#     134     if not torch.cuda.is_available():
# --> 135         raise RuntimeError('Attempting to deserialize object on a CUDA '
#     136                            'device but torch.cuda.is_available() is False. '
#     137                            'If you are running on a CPU-only machine, '
#
# RuntimeError: Attempting to deserialize object on a CUDA device but torch.cuda.is_available() is False. If you are running on a CPU-only machine, please use torch.load with map_location=torch.device('cpu') to map your storages to the CPU.
