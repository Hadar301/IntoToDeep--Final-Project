# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Choose User Path

# %%
from enum import Enum
class Pathes(Enum):
  HADAR = 1
  RAN = 2
  ITAMAR = 3

# %%
import sys

##Just choose here the user
path = Pathes.ITAMAR

if(path == Pathes.HADAR):
  PATH='/content/gdrive/My Drive/IntroToDeep/Project/codes/Model_Seq2Seq_Attention/Weights.pt'
  sys.path.insert(0,'/content/gdrive/My Drive/IntroToDeep/Project/codes/Model_Seq2Seq_Attention')
  train_file = '/content/gdrive/My Drive/IntroToDeep/Project/codes/data/train.txt'
  test_file = '/content/gdrive/My Drive/IntroToDeep/Project/codes/data/test.txt'
  w2v_file = '/content/gdrive/My Drive/IntroToDeep/Project/codes/data/glove.6B.100d.txt'
elif(path == Pathes.RAN):
  PATH='/content/gdrive/My Drive/IntroToDeep/Project/codes/Model_Seq2Seq_Attention/Weights.pt'
  sys.path.insert(0,'/content/gdrive/My Drive/IntroToDeep/Project/codes/Model_Seq2Seq_Attention')
  train_file = '/content/gdrive/My Drive/IntroToDeep/Project/codes/data/train.txt'
  test_file = '/content/gdrive/My Drive/IntroToDeep/Project/codes/data/test.txt'
  w2v_file = '/content/gdrive/My Drive/IntroToDeep/Project/codes/data/glove.6B.100d.txt'
elif(path == Pathes.ITAMAR):
  PATH='/content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Seq2Seq_Attention/Weights.pt'
  sys.path.insert(0,'/content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Seq2Seq_Attention')
  #train_file = '/content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/data/train.txt'
  train_file = '/content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/data/new_train.txt'
  test_file = '/content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/data/test.txt'
  val_file = '/content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/data/validation.txt'
  w2v_file = '/content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/data/glove.6B.100d.txt'

# %% [markdown]
# # Import code

# %%
from utils import *

from model import *
from config import Config
#from utils_Combined import *
#from model import *
#from config import Config

import torch
import torch.optim as optim
from torch import nn

config = Config()

# %%
config.max_epochs = 10 #Max 15

# %% [markdown]
# # Load Data + Embedding

# %%
##########
#Embedding
##########

dataset = Dataset(config)
dataset.load_data(w2v_file, train_file, test_file, val_file)
# Out:
# 100%|█████████▉| 399999/400000 [00:22<00:00, 17587.57it/s]
# Loaded 128000 training examples
# Loaded 40000 test examples
# Loaded 32000 validation examples

# %%
# Create Model with specified optimizer and loss function
##############################################################
model = Seq2SeqAttention(config, len(dataset.vocab), dataset.word_embeddings)
if torch.cuda.is_available():
    model.cuda()
model.train()
optimizer = optim.SGD(model.parameters(), lr=config.lr)
NLLLoss = nn.NLLLoss()
model.add_optimizer(optimizer)
model.add_loss_op(NLLLoss)
##############################################################

# %%
train_losses = []
val_accuracies = []

for i in range(config.max_epochs):
    print ("Epoch: {}".format(i))
   
    train_loss,val_accuracy = model.run_epoch(dataset.train_iterator, dataset.val_iterator, i)
    train_losses.append(train_loss)
    val_accuracies.append(val_accuracy)

train_acc = evaluate_model(model, dataset.train_iterator)
val_acc = evaluate_model(model, dataset.val_iterator)
test_acc = evaluate_model(model, dataset.test_iterator)

print ('Final Training Accuracy: {:.4f}'.format(train_acc))
print ('Final Validation Accuracy: {:.4f}'.format(val_acc))
print ('Final Test Accuracy: {:.4f}'.format(test_acc))

##Save only at one run the weights - run with best parameters##
#save weights
print('--------Weights saved------------')
torch.save(model, PATH)
# Out:
# Epoch: 0
# Iter: 1
# 	Average training loss: -0.25546
# 	Val Accuracy: 0.2777
# Iter: 101
# 	Average training loss: -0.39576
# 	Val Accuracy: 0.5024
# Iter: 201
# 	Average training loss: -0.52101
# 	Val Accuracy: 0.5208
# Iter: 301
# 	Average training loss: -0.56398
# 	Val Accuracy: 0.7290
# Iter: 401
# 	Average training loss: -0.66287
# 	Val Accuracy: 0.8201
# Iter: 501
# 	Average training loss: -0.76017
# 	Val Accuracy: 0.8514
# Iter: 601
# 	Average training loss: -0.82050
# 	Val Accuracy: 0.8329
# Iter: 701
# 	Average training loss: -0.85189
# 	Val Accuracy: 0.8950
# Iter: 801
# 	Average training loss: -0.86542
# 	Val Accuracy: 0.8712
# Iter: 901
# 	Average training loss: -0.87946
# 	Val Accuracy: 0.9084
# Epoch: 1
# Iter: 1
# 	Average training loss: -0.90952
# 	Val Accuracy: 0.9089
# Iter: 101
# 	Average training loss: -0.89045
# 	Val Accuracy: 0.8998
# Iter: 201
# 	Average training loss: -0.90023
# 	Val Accuracy: 0.8964
# Iter: 301
# 	Average training loss: -0.89990
# 	Val Accuracy: 0.9146
# Iter: 401
# 	Average training loss: -0.90574
# 	Val Accuracy: 0.9147
# Iter: 501
# 	Average training loss: -0.88818
# 	Val Accuracy: 0.9176
# Iter: 601
# 	Average training loss: -0.90559
# 	Val Accuracy: 0.9155
# Iter: 701
# 	Average training loss: -0.90748
# 	Val Accuracy: 0.9234
# Iter: 801
# 	Average training loss: -0.91543
# 	Val Accuracy: 0.9157
# Iter: 901
# 	Average training loss: -0.90641
# 	Val Accuracy: 0.9183
# Epoch: 2
# Iter: 1
# 	Average training loss: -0.91728
# 	Val Accuracy: 0.8944
# Iter: 101
# 	Average training loss: -0.90952
# 	Val Accuracy: 0.9173
# Iter: 201
# 	Average training loss: -0.90788
# 	Val Accuracy: 0.9075
# Iter: 301
# 	Average training loss: -0.91590
# 	Val Accuracy: 0.9273
# Iter: 401
# 	Average training loss: -0.91814
# 	Val Accuracy: 0.9232
# Iter: 501
# 	Average training loss: -0.91934
# 	Val Accuracy: 0.9301
# Iter: 601
# 	Average training loss: -0.92310
# 	Val Accuracy: 0.9289
# Iter: 701
# 	Average training loss: -0.92114
# 	Val Accuracy: 0.9280
# Iter: 801
# 	Average training loss: -0.92262
# 	Val Accuracy: 0.9221
# Iter: 901
# 	Average training loss: -0.92232
# 	Val Accuracy: 0.9316
# Epoch: 3
# Reducing LR
# Iter: 1
# 	Average training loss: -0.91188
# 	Val Accuracy: 0.9321
# Iter: 101
# 	Average training loss: -0.92928
# 	Val Accuracy: 0.9271
# Iter: 201
# 	Average training loss: -0.92726
# 	Val Accuracy: 0.9322
# Iter: 301
# 	Average training loss: -0.92856
# 	Val Accuracy: 0.9327
# Iter: 401
# 	Average training loss: -0.92948
# 	Val Accuracy: 0.9342
# Iter: 501
# 	Average training loss: -0.93179
# 	Val Accuracy: 0.9323
# Iter: 601
# 	Average training loss: -0.92695
# 	Val Accuracy: 0.9359
# Iter: 701
# 	Average training loss: -0.92943
# 	Val Accuracy: 0.9349
# Iter: 801
# 	Average training loss: -0.92605
# 	Val Accuracy: 0.9281
# Iter: 901
# 	Average training loss: -0.93095
# 	Val Accuracy: 0.9330
# Epoch: 4
# Iter: 1
# 	Average training loss: -0.89548
# 	Val Accuracy: 0.9276
# Iter: 101
# 	Average training loss: -0.93203
# 	Val Accuracy: 0.9325
# Iter: 201
# 	Average training loss: -0.93103
# 	Val Accuracy: 0.9332
# Iter: 301
# 	Average training loss: -0.93065
# 	Val Accuracy: 0.9308
# Iter: 401
# 	Average training loss: -0.92723
# 	Val Accuracy: 0.9367
# Iter: 501
# 	Average training loss: -0.93352
# 	Val Accuracy: 0.9348
# Iter: 601
# 	Average training loss: -0.93008
# 	Val Accuracy: 0.9307
# Iter: 701
# 	Average training loss: -0.93061
# 	Val Accuracy: 0.9320
# Iter: 801
# 	Average training loss: -0.93225
# 	Val Accuracy: 0.9374
# Iter: 901
# 	Average training loss: -0.93109
# 	Val Accuracy: 0.9134
# Epoch: 5
# Iter: 1
# 	Average training loss: -0.90764
# 	Val Accuracy: 0.9284
# Iter: 101
# 	Average training loss: -0.93550
# 	Val Accuracy: 0.9376
# Iter: 201
# 	Average training loss: -0.93060
# 	Val Accuracy: 0.9289
# Iter: 301
# 	Average training loss: -0.93378
# 	Val Accuracy: 0.9369
# Iter: 401
# 	Average training loss: -0.93721
# 	Val Accuracy: 0.9271
# Iter: 501
# 	Average training loss: -0.92936
# 	Val Accuracy: 0.9335
# Iter: 601
# 	Average training loss: -0.93386
# 	Val Accuracy: 0.9383
# Iter: 701
# 	Average training loss: -0.93241
# 	Val Accuracy: 0.9365
# Iter: 801
# 	Average training loss: -0.93535
# 	Val Accuracy: 0.9338
# Iter: 901
# 	Average training loss: -0.93234
# 	Val Accuracy: 0.9387
# Epoch: 6
# Reducing LR
# Iter: 1
# 	Average training loss: -0.91806
# 	Val Accuracy: 0.9361
# Iter: 101
# 	Average training loss: -0.93604
# 	Val Accuracy: 0.9392
# Iter: 201
# 	Average training loss: -0.93833
# 	Val Accuracy: 0.9390
# Iter: 301
# 	Average training loss: -0.93726
# 	Val Accuracy: 0.9377
# Iter: 401
# 	Average training loss: -0.93798
# 	Val Accuracy: 0.9393
# Iter: 501
# 	Average training loss: -0.93727
# 	Val Accuracy: 0.9366
# Iter: 601
# 	Average training loss: -0.93686
# 	Val Accuracy: 0.9402
# Iter: 701
# 	Average training loss: -0.93654
# 	Val Accuracy: 0.9377
# Iter: 801
# 	Average training loss: -0.93410
# 	Val Accuracy: 0.9405
# Iter: 901
# 	Average training loss: -0.93663
# 	Val Accuracy: 0.9373
# Epoch: 7
# Iter: 1
# 	Average training loss: -0.96490
# 	Val Accuracy: 0.9407
# Iter: 101
# 	Average training loss: -0.93820
# 	Val Accuracy: 0.9383
# Iter: 201
# 	Average training loss: -0.93843
# 	Val Accuracy: 0.9403
# Iter: 301
# 	Average training loss: -0.94050
# 	Val Accuracy: 0.9334
# Iter: 401
# 	Average training loss: -0.94139
# 	Val Accuracy: 0.9404
# Iter: 501
# 	Average training loss: -0.93666
# 	Val Accuracy: 0.9387
# Iter: 601
# 	Average training loss: -0.93474
# 	Val Accuracy: 0.9352
# Iter: 701
# 	Average training loss: -0.93348
# 	Val Accuracy: 0.9369
# Iter: 801
# 	Average training loss: -0.93801
# 	Val Accuracy: 0.9408
# Iter: 901
# 	Average training loss: -0.93817
# 	Val Accuracy: 0.9403
# Epoch: 8
# Iter: 1
# 	Average training loss: -0.94211
# 	Val Accuracy: 0.9393
# Iter: 101
# 	Average training loss: -0.93868
# 	Val Accuracy: 0.9412
# Iter: 201
# 	Average training loss: -0.94004
# 	Val Accuracy: 0.9411
# Iter: 301
# 	Average training loss: -0.93489
# 	Val Accuracy: 0.9412
# Iter: 401
# 	Average training loss: -0.93894
# 	Val Accuracy: 0.9420
# Iter: 501
# 	Average training loss: -0.93875
# 	Val Accuracy: 0.9418
# Iter: 601
# 	Average training loss: -0.94006
# 	Val Accuracy: 0.9388
# Iter: 701
# 	Average training loss: -0.93732
# 	Val Accuracy: 0.9370
# Iter: 801
# 	Average training loss: -0.93808
# 	Val Accuracy: 0.9389
# Iter: 901
# 	Average training loss: -0.93983
# 	Val Accuracy: 0.9426
# Epoch: 9
# Iter: 1
# 	Average training loss: -0.93658
# 	Val Accuracy: 0.9402
# Iter: 101
# 	Average training loss: -0.93717
# 	Val Accuracy: 0.9408
# Iter: 201
# 	Average training loss: -0.93574
# 	Val Accuracy: 0.9383
# Iter: 301
# 	Average training loss: -0.93845
# 	Val Accuracy: 0.9410
# Iter: 401
# 	Average training loss: -0.93809
# 	Val Accuracy: 0.9411
# Iter: 501
# 	Average training loss: -0.93926
# 	Val Accuracy: 0.9419
# Iter: 601
# 	Average training loss: -0.94138
# 	Val Accuracy: 0.9423
# Iter: 701
# 	Average training loss: -0.93856
# 	Val Accuracy: 0.9424
# Iter: 801
# 	Average training loss: -0.94489
# 	Val Accuracy: 0.9408
# Iter: 901
# 	Average training loss: -0.93949
# 	Val Accuracy: 0.9424
# Final Training Accuracy: 0.9431
# Final Validation Accuracy: 0.9428
# Final Test Accuracy: 0.8357
# --------Weights saved------------

# %% [markdown]
# #Metrices

# %%
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
def evaluate_model_metrices(model, iterator):
    y_all_preds = []
    y_all = []
    for idx,batch in enumerate(iterator):
        if torch.cuda.is_available():
            x = batch.text.cuda()
        else:
            x = batch.text
        #raw value from the model
        y_pred = model(x)
        #Round the raw value to 1 or 2 - cutoff Hyperparameter?
        predicted = torch.max(y_pred.cpu().data, 1)[1] + 1

        #extend all Y_lables, Y_predicted to vectors
        y_all_preds.extend(predicted.numpy())
        y_all.extend(batch.label.numpy())

    accuracy = accuracy_score(y_all, np.array(y_all_preds).flatten())
    #precision, recall, fscore = precision_recall_fscore_support(y_all, y_all_preds, average='binary')
    #returns: score - Accuracy score, 
    #         predicted - Array of predicted raw values (just the last batch)
    #         y_all - all the y labels in a vector
    #         y_all_preds - all the predicted values rounded to 1,2
    #         precision, recall, fscore
    return accuracy, predicted, y_all, y_all_preds, #precision, #recall, fscore

# %%
#get vectors
accuracy, predicted, Y_all, Y_all_Preds = evaluate_model_metrices(model, dataset.test_iterator)

# %%
#Precision/Recall
precision_recall_fscore_support(Y_all, Y_all_Preds, average='binary')
# Out:
# (0.6839938598939436, 0.976297181555622, 0.8044147212078939, None)

# %%
#Classification Report
print(classification_report(Y_all, Y_all_Preds))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.76      0.99      0.86     20082
#            2       0.99      0.68      0.80     19918
#
#     accuracy                           0.84     40000
#    macro avg       0.87      0.83      0.83     40000
# weighted avg       0.87      0.84      0.83     40000

# %%
#Confusion Matrix
cm = confusion_matrix(Y_all, Y_all_Preds, labels=[1,2])
print(cm)
# Out:
# [[19606   476]
#  [ 9058 10860]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 8))

heatmap = sns.heatmap(cm, annot=True, fmt="d")
heatmap.set_title('confusion matrix Seq2Seq', fontdict={'fontsize':18}, pad=12);

# %% [markdown]
# # Graphs

# %%
#append to one list
train_loss1 = []
val_accuracies_appended = []

#run until max_epochs 
for i in range(0,config.max_epochs):
  train_loss1.extend(train_losses[i])
  val_accuracies_appended.extend(val_accuracies[i])

print(train_loss1) 
print(len(train_loss1))
print(val_accuracies_appended) 
print(len(val_accuracies_appended))
# Out:
# [-0.25382322, -0.76230574, -0.82773966, -0.8311537, -0.8389767, -0.84528315, -0.8608652, -0.8661012, -0.86251754, -0.86438596]
# 10
# [0.50296875, 0.82609375, 0.83584375, 0.85009375, 0.865625, 0.8555625, 0.8378125, 0.85071875, 0.8240625, 0.88521875]
# 10

# %%
train_loss2 = []
train_loss2 = [x * (-1) for x in train_loss1]

# %%
#print graphs
from matplotlib import pyplot
pyplot.title('Train and Validation Accuracy Seq2Seq')
pyplot.plot(train_loss2, label='train')
pyplot.plot(val_accuracies_appended, label='validation')
pyplot.legend()
pyplot.show()

# %% [markdown]
# # Load Model

# %%
#load model 
model = torch.load(PATH)
model.eval()
# Out:
# Seq2SeqAttention(
#   (embeddings): Embedding(50480, 100)
#   (lstm): LSTM(100, 32, bidirectional=True)
#   (dropout): Dropout(p=0.8, inplace=False)
#   (fc): Linear(in_features=128, out_features=4, bias=True)
#   (softmax): Softmax(dim=-1)
#   (loss_op): NLLLoss()
# )

# %%
#Get Data for Last layer
#Train Set
accuracy_train, predicted_train, Y_all_train, Y_all_Preds_train = evaluate_model_metrices(model, dataset.train_iterator)
#Test Set
accuracy_test, predicted_test, Y_all_test, Y_all_Preds_test = evaluate_model_metrices(model, dataset.test_iterator)

# %%
#Classification Report
print(classification_report(Y_all_test, Y_all_Preds_test))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.67      0.98      0.79     20082
#            2       0.97      0.50      0.66     19918
#
#     accuracy                           0.74     40000
#    macro avg       0.82      0.74      0.73     40000
# weighted avg       0.82      0.74      0.73     40000

# %%
#Classification Report
print(classification_report(Y_all_train, Y_all_Preds_train))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.90      0.91      0.91     63819
#            2       0.91      0.90      0.91     64181
#
#     accuracy                           0.91    128000
#    macro avg       0.91      0.91      0.91    128000
# weighted avg       0.91      0.91      0.91    128000

# %%
import numpy as np
from numpy import asarray

# %%
Y_RNN_Pred_Test = asarray(Y_all_Preds_test, dtype = 'int32')
Y_RNN_GroundProof_Test = asarray(Y_all_test, dtype = 'int32')
Y_RNN_Pred_Train = asarray(Y_all_Preds_train, dtype = 'int32')
Y_RNN_GroundProof_Train = asarray(Y_all_train, dtype = 'int32')

# %%
#Save the tensors
# %cd '/content/gdrive/My Drive/Colab Notebooks/Uni/IntroToDeep/IntroToDeep/Project/codes/Model_Seq2Seq_Attention/'
np.save('Y_Seq2Seq_Pred_Test', Y_RNN_Pred_Test)
np.save('Y_Seq2Seq_GroundProof_Test', Y_RNN_GroundProof_Test)
np.save('Y_Seq2Seq_Pred_Train', Y_RNN_Pred_Train)
np.save('Y_Seq2Seq_GroundProof_Train', Y_RNN_GroundProof_Train)
# Out:
# /content/gdrive/.shortcut-targets-by-id/1XNTZrFPo5LZhTNZ3l5LoLnleAlL4h-1v/IntroToDeep/Project/codes/Model_Seq2Seq_Attention
